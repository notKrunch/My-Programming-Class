# %% [markdown]
# <a href="https://colab.research.google.com/github/notKrunch/My-Programming-Class/blob/main/CHAPTER6/EXERCISE-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# exercise 3

i = 1
while i == 1:
  print('Hello.')
# Out:
# Streaming output truncated to the last 5000 lines.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# Hello.
# ...
